// %% [markdown]
// # Lab 9 Exercise 1
//
// ## การใช้งาน Modifier

// %% [markdown]
// 1. สร้าง console application project
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotbet new conxole --name Lab09_Ex01
// ```

// %% [markdown]
// ถ้ารันคำสั่งไม่ได้ ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 2. เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// > ```csharp
// >   Person.name = "_________________";
// >   System.conso1e.writ1ine(Person.GetName());
// >
// >   static class Person
// >   {
// >       public static st__ng? name;
// >       public static stri__ GetName()
// >       {
// >           return $"Hello from {name}";
// >       }
// >   }
// > ```

// %% [markdown]
// 3. Build project โดยการใช้คำสั่ง
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotdet build  Lab09_Ex0_
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5. Run project โดยการใช้คำสั่ง
//
// ```cmd ควรพิมพ์เอง ดีกว่า copy-paste เพราพมีการแทรกอักษรมั่วๆ เอาไว้
//     dotxet run --project Lab_9_Ex_1
// ```

// %% [markdown]
// 6. บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7. อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// เมื่อรันโค้ดจะแสดงผล เป็น Hello from ตามด้วยชื่อที่เราป้อนไปใน Person.name

// %% [markdown]
// ## คำถาม

// %% [markdown]
// 1. Static field และ static method ต่างจาก instance field และ instance method อย่างไร

// %% [markdown]
// Static field/method เป็นของคลาสโดยรวม ไม่ได้ผูกกับ object ใดๆ เรียกใช้ได้โดยตรงผ่านชื่อคลาส
//
// Instance field/method เป็นของ object ที่สร้างจากคลาส ต้องสร้าง object ก่อนถึงจะเรียกใช้ได้

// %% [markdown]
// 2. เหตุใดเราจึงสามารถเข้าถึง Person.name และ Person.GetName() ได้โดยตรงผ่านชื่อ class โดยไม่ต้องสร้าง object

// %% [markdown]
// เพราะ name และ GetName() ถูกประกาศเป็น static ซึ่งหมายความว่าเป็นสมาชิกของคลาสโดยตรง ไม่จำเป็นต้องสร้าง object

// %% [markdown]
// 3. Static class มีข้อจำกัดอะไรบ้าง

// %% [markdown]
// 1.สร้าง object ไม่ได้
//
// 2.สมาชิกทั้งหมดต้องเป็น static

// %% [markdown]
// 4. เราไม่สามารถสร้าง instance ของ static class ได้เพราะอะไร

// %% [markdown]
// เพราะ static class ถูกออกแบบมาให้ใช้งานในระดับคลาส ไม่ได้ออกแบบมาให้สร้าง object

// %% [markdown]
// 5. ประโยชน์ของการใช้ static class คืออะไร  มีสถานการณ์ใดบ้างที่เราควรใช้ static class

// %% [markdown]
// __ประโยชน์คือ__
//
// 1.Utility class ใช้เก็บ method ที่ทำงานทั่วไป เช่น method สำหรับคำนวณ หรือจัดการ string
//
// 2.Extension method ใช้เพิ่มความสามารถให้กับคลาสที่มีอยู่แล้ว
//
// 3.Singleton ใช้สร้าง class ที่มี object ได้เพียงตัวเดีย
//
// __สถานการณ์ที่ควรใช้__
//
// -เมื่อต้องการ class ที่มี method utility ทั่วไป
//
// -เมื่อต้องการเพิ่มความสามารถให้กับคลาสที่มีอยู่แล้ว
//
// -เมื่อต้องการ class ที่มี object ได้เพียงตัวเดียว
